# %%
from zipline.utils.flightlog_client import enable_flightlog, log_to_flightlog

# Enable FlightLog
try:
    enable_flightlog(host='localhost', port=9020)
    log_to_flightlog('🚀 Multi-Source Strategy - FlightLog Connected', level='INFO')
    print("✅ FlightLog enabled - check your second terminal!")
    FLIGHTLOG_ENABLED = True
except Exception as e:
    print(f"⚠️  FlightLog not available: {e}")
    print("   Continuing without FlightLog...")
    FLIGHTLOG_ENABLED = False
    # Definfcf_yield_strategy
# Out:
# ✅ FlightLog enabled - check your second terminal!

# %%
import sys
sys.path.insert(0, '/app/examples/utils')

from backtest_helpers import backtest

results = backtest(
  algo_filename='/app/examples/strategies/fcf_yield_strategy.py',
  name='top-ev-test',
  start_date='2023-01-01',
  end_date='2024-01-01',
  capital_base=1000000,
  bundle='sharadar',
  algo_name='TopEV-Strategy',
  output_file='my_custom_results.pkl'
)

# %%
import sys
sys.path.insert(0, '/app/examples/utils')

from backtest_helpers import backtest

results = backtest(
  algo_filename='/app/examples/strategies/LS-ZR-ported.py',
  name='top-ev-test',
  start_date='2012-01-01',
  end_date='2025-12-16',
  capital_base=1000000,
  bundle='sharadar',
  algo_name='LS-ZR-ported',
  output_file='my_custom_results-LSZR-entval-ml-15-MLforcast-180-90-10-mlwf-16-resume-rs-estrank-10-2012-t-noffil.pkl'
)
# Out:
# FlightLog LOG connected to localhost:9020
# FlightLog PRINT connected to localhost:9021
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...

# %%
# %flightlog both
